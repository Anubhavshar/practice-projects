# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %% [markdown]
# # Importing CSV File

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.drop(columns = 'Name', inplace = True) #drop the unnecessary column

# %%
df.drop(columns = 'Ticket', inplace = True)#drop the unnecessary column

# %%
df.drop(columns = 'Cabin', inplace = True)#drop the unnecessary column

# %% [markdown]
# Dropping extra columns

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S
# 5            6         0       3    male   NaN      0      0   8.4583        Q
# 6            7         0       1    male  54.0      0      0  51.8625        S
# 7            8         0       3    male   2.0      3      1  21.0750        S
# 8            9         1       3  female  27.0      0      2  11.1333        S
# 9           10         1       2  female  14.0      1      0  30.0708        C

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %% [markdown]
# # RemovingNullValues

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer

# %%
si = SimpleImputer() #using simple imputer to remove null values
ct = make_column_transformer((si, ['Age']), remainder = 'passthrough')
a=ct.fit_transform(df)
df['Age']=a
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder, LabelEncoder

# %%
# Encode categorical variables
label_encoder = LabelEncoder()
df['Sex'] = label_encoder.fit_transform(df['Sex'])
df['Embarked'] = label_encoder.fit_transform(df['Embarked'])

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    1  22.0      1      0   7.2500         2
# 1            2         1       1    0  38.0      1      0  71.2833         0
# 2            3         1       3    0  26.0      0      0   7.9250         2
# 3            4         1       1    0  35.0      1      0  53.1000         2
# 4            5         0       3    1  35.0      0      0   8.0500         2

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.647587    0.523008
# std     257.353842    0.486592    0.836071    0.477990    1.102743
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    0.000000
# 50%     446.000000    0.000000    3.000000    1.000000    0.000000
# 75%     668.500000    1.000000    3.000000    1.000000    1.000000
# max     891.000000    1.000000    3.000000    1.000000    8.000000
#
#             Parch        Fare    Embarked
# count  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    1.536476
# std      0.806057   49.693429    0.791503
# min      0.000000    0.000000    0.000000
# 25%      0.000000    7.910400    1.000000
# 50%      0.000000   14.454200    2.000000
# 75%      0.000000   31.000000    2.000000
# max      6.000000  512.329200    2.000000

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.describe(),annot=True)
plt.show()

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000  0.131900  0.083081  0.018443
# Sex             0.042939 -0.543351  0.131900  1.000000 -0.114631 -0.245489
# SibSp          -0.057527 -0.035322  0.083081 -0.114631  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.245489  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.159651  0.216225
# Embarked        0.013128 -0.167675  0.162098  0.108262  0.068230  0.039798
#
#                  Fare  Embarked
# PassengerId  0.012658  0.013128
# Survived     0.257307 -0.167675
# Pclass      -0.549500  0.162098
# Sex         -0.182333  0.108262
# SibSp        0.159651  0.068230
# Parch        0.216225  0.039798
# Fare         1.000000 -0.224719
# Embarked    -0.224719  1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,linecolor='black',cmap='YlOrRd')
plt.xlabel("Figure",fontsize=20)
plt.ylabel("Features Name",fontsize=20)
plt.title("Descriptive Graph",fontsize=20)
plt.show()

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(20,25),facecolor='green')
p=1
for column in df:
    if p<=18:
        ax=plt.subplot(6,4,p)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    p+=1
plt.show()

# %%
#visaulize the normal distribution of the column by using distplot
plt.figure(figsize=(20,25), facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.histplot(df[column])
        plt.xlabel(column, fontsize=15)
    plotnumber+=1
plt.show()

# %%
sns.pairplot(data=df)

# %%
sns.lineplot(x="Survived",y="Age",data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.lineplot(x="Survived",y="Sex",data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Sex'>

# %%
sns.lineplot(x="Survived",y="Embarked",data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Embarked'>

# %%
sns.lineplot(x="Survived",y="SibSp",data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='SibSp'>

# %%
sns.lineplot(x="Survived",y="Fare",data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
sns.lineplot(x="Survived",y="Parch",data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Parch'>

# %%
plt.figure(figsize=(20,15))
sns.lineplot(data=df.iloc[:,:-1])
plt.ylabel("Titanic Survived")
plt.title("The General Trend Of All Values")
plt.show()

# %% [markdown]
# # Outliers

# %%
#checking Outliers
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=15:
        plt.subplot(5,4,p)
        plt.boxplot(df[i])
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# # Removing Outliers

# %%
#Detecting the outlier by using iqr method and removing them.
q1 = np.percentile(df['Age'], 25,
                   interpolation = 'midpoint')
 
q3 = np.percentile(df['Age'], 75,
                   interpolation = 'midpoint')
iqr = q3 - q1

# %%
# higher side 
higher_side = df['Age'] >= (q3+1.5*iqr)
print("Higher: \n", higher_side)
print(np.where(higher_side))
high = np.where(higher_side)
 
# lower side 
lower_side = df['Age'] <= (q1-1.5*iqr)
print("Lower: \n", lower_side)
low = np.where(lower_side)
print(np.where(lower_side))
print("old Shape: ", df.shape)
# Out:
# Higher:
#  0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool
# (array([ 11,  15,  33,  54,  94,  96, 116, 152, 170, 174, 195, 232, 252,
#        268, 275, 280, 326, 366, 438, 456, 467, 483, 487, 492, 493, 545,
#        555, 570, 587, 625, 626, 630, 647, 659, 672, 684, 694, 745, 772,
#        829, 851, 879], dtype=int64),)
# Lower:
#  0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool
# (array([  7,  16,  78, 119, 164, 172, 183, 205, 297, 305, 340, 381, 386,
#        469, 479, 530, 642, 644, 755, 788, 803, 824, 827, 831], dtype=int64),)
# old Shape:  (891, 9)

# %%
#removing the outliers
print("Old Shape: ", df.shape)
df = df.drop(df.index[high])
df = df.drop(df.index[low])
 
print("New Shape: ", df.shape)
# Out:
# Old Shape:  (891, 9)
# New Shape:  (825, 9)

# %%
#Detecting the outlier by using iqr method and removing them.
q1 = np.percentile(df['Fare'], 25,
                   interpolation = 'midpoint')
 
q3 = np.percentile(df['Fare'], 60,
                   interpolation = 'midpoint')
iqr = q3 - q1

# %%
# higher side 
higher_side = df['Fare'] >= (q3+1.5*iqr)
print("Higher:", higher_side)
print(np.where(higher_side))
high = np.where(higher_side)
 
# lower side 
lower_side = df['Fare'] <= (q1-1.5*iqr)
print("Lower:", lower_side)
low = np.where(lower_side)
print(np.where(lower_side))
print("old Shape: ", df.shape)
# Out:
# Higher: 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 825, dtype: bool
# (array([  1,   3,   6,  23,  27,  29,  30,  38,  47,  53,  55,  56,  65,
#         66,  68,  76,  81,  85,  88,  93, 101, 108, 110, 114, 126, 128,
#        140, 143, 147, 154, 157, 165, 169, 183, 197, 199, 205, 211, 225,
#        228, 235, 236, 237, 241, 247, 266, 267, 273, 275, 281, 282, 283,
#        285, 286, 287, 293, 294, 298, 299, 302, 305, 307, 309, 310, 314,
#        329, 340, 341, 344, 346, 348, 351, 354, 356, 357, 361, 364, 381,
#        403, 404, 413, 421, 424, 441, 446, 449, 451, 457, 459, 465, 469,
#        473, 480, 483, 487, 497, 499, 500, 504, 509, 515, 527, 533, 537,
#        541, 546, 554, 557, 563, 564, 570, 576, 580, 593, 595, 597, 606,
#        610, 615, 619, 621, 626, 628, 630, 631, 635, 636, 638, 643, 645,
#        653, 655, 657, 661, 669, 675, 682, 686, 687, 692, 698, 703, 707,
#        709, 722, 724, 732, 735, 744, 751, 762, 768, 775, 778, 785, 788,
#        794, 801, 804, 807], dtype=int64),)
# Lower: 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 825, dtype: bool
# (array([], dtype=int64),)
# old Shape:  (825, 9)

# %%
#removing the outliers
df = df.drop(df.index[low])
df = df.drop(df.index[high])
 
print("New Shape: ", df.shape)
# Out:
# New Shape:  (665, 9)

# %%
sns.boxplot(data = df['Fare'])
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder, LabelEncoder, PowerTransformer
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.feature_selection import SelectPercentile, chi2
from sklearn.metrics import mean_squared_error, mean_absolute_error, roc_curve, roc_auc_score, plot_roc_curve
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import statistics as st
import statsmodels.api as sm
import pickle
from sklearn.metrics import r2_score

# %% [markdown]
# # Scaling Of Data

# %%
#split x and y
x = df.drop(['Survived'], axis=1)
y=df.Survived

# %%
x.shape
# Out:
# (665, 8)

# %%
y.shape
# Out:
# (665,)

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[-1.72904374,  0.63888802,  0.6770032 , ..., -0.42913454,
#         -0.82013774,  0.54020325],
#        [-1.72129828,  0.63888802, -1.47709789, ..., -0.42913454,
#         -0.74585525,  0.54020325],
#        [-1.71355281,  0.63888802,  0.6770032 , ..., -0.42913454,
#         -0.73209923,  0.54020325],
#        ...,
#        [ 1.70994215,  0.63888802, -1.47709789, ...,  2.16517884,
#          0.96264203,  0.54020325],
#        [ 1.71381488, -2.49661406,  0.6770032 , ..., -0.42913454,
#          1.68345731, -2.22314416],
#        [ 1.71768761,  0.63888802,  0.6770032 , ..., -0.42913454,
#         -0.76511367, -0.84147045]])

# %% [markdown]
# # Variance Inflation Factor

# %%
# Check the multicollinearity between the features
#import library for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["vif"]= [ variance_inflation_factor(x_scaled, i)
               for i in range ( x_scaled.shape[1])]
vif['features']= x.columns
vif #less corelation between the features
# Out:
#         vif     features
# 0  1.014008  PassengerId
# 1  2.131755       Pclass
# 2  1.129194          Sex
# 3  1.221504          Age
# 4  1.913734        SibSp
# 5  1.631291        Parch
# 6  3.049478         Fare
# 7  1.027830     Embarked

# %% [markdown]
# # Modelling Of Data

# %%
#split data into train and test.
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y,test_size = 0.25, random_state=42)

# %%
y_train.head()
# Out:
# 122    0
# 668    0
# 471    0
# 650    0
# 719    0
# Name: Survived, dtype: int64

# %% [markdown]
# # Logistic Regression

# %%
#Model instantiating and training
log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#Cross validation score for logistic regression
lr_cv = log_reg.predict(x_test)
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
lr_acc= accuracy_score(y_test,lr_cv)

lr_score= cross_val_score(log_reg,x,y,cv=5)
lr_sc=lr_score.mean()

print("CV Score is:",lr_sc*100)
print("Accuracy Score is:",lr_acc*100)
print("\n")
# Out:
# CV Score is: 78.34586466165415
# Accuracy Score is: 73.65269461077844

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# # KNeighbors Classifiers

# %%
Classifier = KNeighborsClassifier(n_neighbors=5)
Classifier.fit(x_train,y_train) #first train the data
Classifier.score(x_train,y_train) #train data score
Classifier.score(x_test,y_test) #test data score
knn = KNeighborsClassifier()
knn.fit(x_train,y_train) #train the data
y_pred = knn.predict(x_test) #predict the data
cf = confusion_matrix(y_test, y_pred) #make confusion matrix
cf
# Out:
# array([[96, 18],
#        [25, 28]], dtype=int64)

# %%
print(classification_report(y_test,y_pred,digits=2)) #make classification report
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.82       114
#            1       0.61      0.53      0.57        53
#
#     accuracy                           0.74       167
#    macro avg       0.70      0.69      0.69       167
# weighted avg       0.73      0.74      0.74       167

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(knn,x_scaled,y,cv=5)
cross_val_score(KNeighborsClassifier(),x_scaled,y,cv=5).mean() #mean of the cv score
# Out:
# 0.8030075187969924

# %%
print('\n Accuracy Score---', accuracy_score(y_test, y_pred))
# Out:
#  Accuracy Score--- 0.7425149700598802

# %%
from sklearn.svm import SVC

# %% [markdown]
# # Support Vector Classifier

# %%
svc = SVC()
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
svc.score(x_test,y_test)
y_pred = svc.predict(x_test)
print('\n Accuracy Score---', accuracy_score(y_test, y_pred)) #get accuracy score
cross_val_score(svc,x_scaled,y,cv=5)
cross_val_score(SVC(),x_scaled,y,cv=5).mean() #mean of the cv score
# Out:
#  Accuracy Score--- 0.7604790419161677
# 0.7984962406015037

# %%
cf = confusion_matrix(y_test, y_pred)
cf #confusin matrix
# Out:
# array([[97, 17],
#        [23, 30]], dtype=int64)

# %%
print(classification_report(y_test,y_pred,digits=2)) #make classification report
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83       114
#            1       0.64      0.57      0.60        53
#
#     accuracy                           0.76       167
#    macro avg       0.72      0.71      0.71       167
# weighted avg       0.75      0.76      0.76       167

# %% [markdown]
# # RandomForest Classifier

# %%
rf= RandomForestClassifier() 
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
rf.score(x_test,y_test)
y_pred = rf.predict(x_test)
print('\n Accuracy Score---', accuracy_score(y_test, y_pred)) #get accuracy score
cross_val_score(rf,x_scaled,y,cv=5)
cross_val_score(RandomForestClassifier(),x_scaled,y,cv=5).mean() #mean of the cv score
# Out:
#  Accuracy Score--- 0.7844311377245509
# 0.8015037593984962

# %%
cf = confusion_matrix(y_test, y_pred)
cf #confusin matrix
# Out:
# array([[100,  14],
#        [ 20,  33]], dtype=int64)

# %%
print(classification_report(y_test,y_pred,digits=2)) #make classification report
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       114
#            1       0.70      0.62      0.66        53
#
#     accuracy                           0.80       167
#    macro avg       0.77      0.75      0.76       167
# weighted avg       0.79      0.80      0.79       167

# %% [markdown]
# # Decision Tree Classifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
dtc.score(x_test,y_test)
y_pred = dtc.predict(x_test)
print('\n Accuracy Score---', accuracy_score(y_test, y_pred)) #get accuracy score

cross_val_score(dtc,x_scaled,y,cv=5)
cross_val_score(DecisionTreeClassifier(),x_scaled,y,cv=5).mean() #mean of the cv score
# Out:
#  Accuracy Score--- 0.7485029940119761
# 0.7263157894736842

# %%
cf = confusion_matrix(y_test, y_pred)
cf #confusin matrix
# Out:
# array([[94, 20],
#        [22, 31]], dtype=int64)

# %%
print(classification_report(y_test,y_pred,digits=2)) #make classification report
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       114
#            1       0.62      0.66      0.64        53
#
#     accuracy                           0.77       167
#    macro avg       0.73      0.74      0.73       167
# weighted avg       0.77      0.77      0.77       167

# %%
from sklearn.model_selection import GridSearchCV #import libary

# %% [markdown]
# # Grid Search CV

# %%
rf = RandomForestClassifier()
grid_space={'max_depth':[3,5,10,None],
              'n_estimators':[10,100,200],
              'max_features':[1,3,5,7],
              'min_samples_leaf':[1,2,3],
              'min_samples_split':[1,2,3]
           }

# %%
grid = GridSearchCV(rf,param_grid=grid_space,cv=3,scoring='accuracy')
model_grid = grid.fit(x,y)

# %%
print('Best hyperparameters are: '+str(model_grid.best_params_))
print('Best score is: '+str(model_grid.best_score_))
# Out:
# Best hyperparameters are: {'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
# Best score is: 0.8105118693353988

# %% [markdown]
# # Final Model

# %%
Model=RandomForestClassifier(max_depth=3,max_features=3,min_samples_leaf=1,min_samples_split=3,n_estimators=200)

# %%
import joblib
import pickle

# %%
filename="TitanicSurvivors.pkl"
pickle.dump(Model,open(filename,'wb'))
